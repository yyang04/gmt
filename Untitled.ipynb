# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time

options = webdriver.ChromeOptions()
options.binary_location = r"/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
options.add_argument(r'/Users/guanmengting/Library/Application Support/Google/Chrome/')
options.add_argument('--disable-blink-features=AutomationControlled')
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)

# %%
driver.get("https://www.taobao.com")
driver.find_element(By.LINK_TEXT, "亲，请登录").click()
driver.find_element(By.CSS_SELECTOR, "i.iconfont.icon-qrcode").click()

# %%
def current_window():
    windowstabs = driver.window_handles
    current = driver.current_window_handle
    return windowstabs.index(current)

def switch_window(index):
    windowstabs = driver.window_handles
    driver.switch_to.window(windowstabs[index])
    return current_window()

def close_window():
    driver.close()
    switch_window(-1)

# %%
switch_window(-1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File ~/anaconda3/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fb7e253c6d0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 switch_window(-1)
#
# Cell In[23], line 7, in switch_window(index)
#       6 def switch_window(index):
# ----> 7     windowstabs = driver.window_handles
#       8     driver.switch_to.window(windowstabs[index])
#       9     return current_window()
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784 elif isinstance(e, (SocketError, HTTPException)):
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#     792 # Keep track of the error for the retry warning.
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=49177): Max retries exceeded with url: /session/2e695a84f12bfa7f59a5d15c99119f03/window/handles (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fb7e253c6d0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
def parse_web_page():
    switch_window(-1)
    item_name = driver.find_element(By.CSS_SELECTOR, 'h1.ItemHeader--mainTitle--3CIjqW5').text
    sale_month = driver.find_element(By.CSS_SELECTOR, 'span.ItemHeader--salesDesc--srlk2Hv').text
    skuValueName = [element.text for element in driver.find_elements(By.CSS_SELECTOR, 'span.skuValueName')]
    price = driver.find_element(By.CSS_SELECTOR, 'span.Price--priceText--2nLbVda').text
    sales_price = driver.find_elements(By.CSS_SELECTOR, 'span.Price--extraPriceText--2dbLkGw')
    sales_price = sales_price[0].text if sales_price else -1

    ret = {
        "item_name": item_name,
        "sale_month": sale_month,
        "skuValueName": skuValueName,
        "price": price,
        "sales_price": sales_price,
        "link": driver.current_url
    }
    close_window()
    return ret

# %%
result = []

# %%
switch_window(-1)
for item in driver.find_elements(By.CSS_SELECTOR, 'dd.detail'):
    item.find_element(By.CSS_SELECTOR, 'a.item-name').click()
    time.sleep(5)
    resultEntity = parse_web_page()
    resultEntity.update({'total_sale': item.find_element(By.CSS_SELECTOR, 'span.sale-num').text})
    result.append(resultEntity)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 5
#       3 item.find_element(By.CSS_SELECTOR, 'a.item-name').click()
#       4 time.sleep(5)
# ----> 5 resultEntity = parse_web_page()
#       6 resultEntity.update({'total_sale': item.find_element(By.CSS_SELECTOR, 'span.sale-num').text})
#       7 result.append(resultEntity)
#
# Cell In[15], line 2, in parse_web_page()
#       1 def parse_web_page():
# ----> 2     switch_window(-1)
#       3     item_name = driver.find_element(By.CSS_SELECTOR, 'h1.ItemHeader--mainTitle--3CIjqW5').text
#       4     sale_month = driver.find_element(By.CSS_SELECTOR, 'span.ItemHeader--salesDesc--srlk2Hv').text
#
# Cell In[10], line 7, in switch_window(index)
#       6 def switch_window(index):
# ----> 7     windowstabs = driver.window_handles
#       8     driver.switch_to.window(windowstabs[index])
#       9     return current_window()
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
result
# Out:
# [{'item_name': 'MAVO巫师2.0手摇磨豆机 咖啡豆研磨机 手磨咖啡机磨豆器手动CNC',
#   'sale_month': '月销 1000+',
#   'skuValueName': ['巫师1.0-全能版（深空灰）',
#    '巫师1.0-全能版（粉金*深空灰）',
#    '巫师1.0-全能版（粉金）',
#    '巫师1.0-意式版（深空灰）',
#    '巫师1.0-意式版（粉金*深空灰）',
#    '巫师2.0-全能版（曜岩黑）',
#    '巫师2.0-全能版（星光银）',
#    '巫师2.0-意式版（曜岩黑）',
#    '巫师2.0-意式版（星光银）'],
#   'price': '298',
#   'sales_price': '288',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627361225217&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.42.6808559f34xcn7',
#   'total_sale': '4万+'},
#  {'item_name': 'MAVO手冲咖啡壶套装礼盒 咖啡全套 手冲壶磨豆机分享壶滤杯礼品',
#   'sale_month': '月销 500+',
#   'skuValueName': ['MAVO 2号咖啡集装箱-LITE版（黑色2.0）',
#    'MAVO 2号咖啡集装箱-LITE版（白色2.0）',
#    'MAVO 2号咖啡礼盒',
#    'MAVO 2号咖啡礼盒（黑色2.0）',
#    'MAVO 2号咖啡礼盒（白色2.0）'],
#   'price': '599',
#   'sales_price': '559',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=657601536249&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.46.6808559f34xcn7',
#   'total_sale': '1万+'},
#  {'item_name': 'MAVO法压壶 咖啡壶过滤杯器具 茶壶手冲家用法式滤压 双层滤网',
#   'sale_month': '月销 500+',
#   'skuValueName': ['350ml 1-2人份', '600ml 2-3人份'],
#   'price': '78',
#   'sales_price': '68',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627043280684&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.50.6808559f34xcn7',
#   'total_sale': '2万+'},
#  {'item_name': 'MAVO咖啡滤纸 手冲咖啡过滤纸 V60日本进口滤纸100张 可食用级',
#   'sale_month': '月销 200+',
#   'skuValueName': ['V01 100张入', 'V02 100张入'],
#   'price': '35',
#   'sales_price': '33',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627367277735&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.54.6808559f34xcn7',
#   'total_sale': '6000+'},
#  {'item_name': 'MAVO奶泡机 打奶泡器手持咖啡牛奶 打泡器手动奶泡壶 打发器玻璃',
#   'sale_month': '月销 400+',
#   'skuValueName': ['米白'],
#   'price': '58',
#   'sales_price': '48',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627665622482&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.58.6808559f34xcn7&skuId=4622084906438',
#   'total_sale': '2万+'},
#  {'item_name': 'MAVO雪白法压壶 咖啡壶煮咖啡家用小型滤茶壶过滤杯 冬季限定玻璃',
#   'sale_month': '月销 400+',
#   'skuValueName': ['350ml 1-2人份（雪白）',
#    '600ml 2-3人份（雪白）',
#    '350ml 1-2人份（曜岩黑）',
#    '600ml 2-3人份（曜岩黑）'],
#   'price': '68',
#   'sales_price': '58',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=635516176193&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.62.6808559f34xcn7',
#   'total_sale': '9000+'},
#  {'item_name': 'MAVO法压壶 咖啡壶橄榄木 咖啡过滤杯器具 茶壶家用法式压杯壶',
#   'sale_month': '月销 78',
#   'skuValueName': ['350ml 1-2人份', '600ml 2-3人份'],
#   'price': '128',
#   'sales_price': '118',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627367917786&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.66.6808559f34xcn7',
#   'total_sale': '7000+'},
#  {'item_name': 'MAVO手冲壶手冲咖啡壶 挂耳咖啡器具滴漏 长嘴细口壶家用不锈钢',
#   'sale_month': '月销 61',
#   'skuValueName': ['曜岩黑X古铜', '水泥灰', '朱鹭白'],
#   'price': '158',
#   'sales_price': '138',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=647738997975&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.70.6808559f34xcn7',
#   'total_sale': '3000+'},
#  {'item_name': 'MAVO手冲咖啡壶套装礼盒 全套咖啡器具家用便携 手冲壶分享壶滤杯',
#   'sale_month': '月销 100+',
#   'skuValueName': ['MAVO小鲸套装 蜜瓜绿', 'MAVO小鲸套装 深空灰', 'MAVO小鲸套装 假日黄'],
#   'price': '248',
#   'sales_price': '238',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=704950257551&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.74.6808559f34xcn7',
#   'total_sale': '200+'},
#  {'item_name': 'MAVO精灵咖啡电子秤 手冲咖啡秤称重 烘焙厨房吧台 智能计时',
#   'sale_month': '月销 71',
#   'skuValueName': [],
#   'price': '168',
#   'sales_price': '158',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627967037647&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.78.6808559f34xcn7',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO 咖啡粉清洁气吹 磨豆机清洁 相机 精密仪器除尘工具',
#   'sale_month': '月销 200+',
#   'skuValueName': ['黑色'],
#   'price': '38',
#   'sales_price': -1,
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=654796873943&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.82.6808559f34xcn7&skuId=4901806971936',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO挂耳滤纸咖啡滤纸 咖啡滤袋手冲过滤纸 挂耳包咖啡过滤器',
#   'sale_month': '月销 100+',
#   'skuValueName': ['50张 滤纸'],
#   'price': '28',
#   'sales_price': '25',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=657085056980&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.86.6808559f34xcn7&skuId=4747528921822',
#   'total_sale': '3000+'},
#  {'item_name': 'MAVO目黑手冲咖啡壶套装 过滤杯器具 细口长嘴滤壶 手冲杯分享壶',
#   'sale_month': '月销 43',
#   'skuValueName': ['目黑·套装(手冲壶+滤杯+分享壶)赠黑石温度计'],
#   'price': '218',
#   'sales_price': '198',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627041644327&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.90.6808559f34xcn7&skuId=4449960696995',
#   'total_sale': '3000+'},
#  {'item_name': 'MAVO尼德兰冷萃咖啡壶 冷泡冰滴咖啡壶 过滤杯冷萃茶壶 双层滤网',
#   'sale_month': '月销 47',
#   'skuValueName': ['1200毫升 双层滤网'],
#   'price': '138',
#   'sales_price': '128',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627665546096&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.94.6808559f34xcn7&skuId=4449969476464',
#   'total_sale': '2000+'},
#  {'item_name': 'MAVO咖啡豆保存罐 咖啡粉密封罐 玻璃抽真空 按压单向排气 大容量',
#   'sale_month': '月销 66',
#   'skuValueName': ['400ml', '800ml', '1200ml'],
#   'price': '68',
#   'sales_price': '63',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=631429076004&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.98.6808559f34xcn7',
#   'total_sale': '1万+'},
#  {'item_name': 'MAVO拾光师玻璃咖啡杯 马克杯 带手把ins风琥珀色粉红透明复古',
#   'sale_month': '月销 46',
#   'skuValueName': ['琥珀', '樱粉', '透明'],
#   'price': '28',
#   'sales_price': '23',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627367937185&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.102.6808559f34xcn7',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO手冲咖啡滤杯 v60滤杯 家用咖啡器具套装 兼容v01v02滤纸陶瓷',
#   'sale_month': '月销 40',
#   'skuValueName': ['黑翼陶瓷滤杯 v01v02通用'],
#   'price': '78',
#   'sales_price': '68',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=630714658176&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.106.6808559f34xcn7&skuId=4485512224380',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO咖啡温度计 手冲打奶泡拉花温度计 不锈钢探针夹可水洗调节',
#   'sale_month': '月销 65',
#   'skuValueName': ['无螺纹版', '螺纹版'],
#   'price': '38',
#   'sales_price': '36',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=649881494576&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.110.6808559f34xcn7',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO小鲸手冲咖啡壶套装 家用便携全套咖啡器具 手冲壶分享壶滤杯',
#   'sale_month': '月销 42',
#   'skuValueName': ['小鲸套装 蜜瓜绿', '小鲸套装 深空灰', '小鲸套装 假日黄'],
#   'price': '248',
#   'sales_price': '238',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=685078021517&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.114.6808559f34xcn7',
#   'total_sale': '500+'},
#  {'item_name': 'MAVO小黑卡 研磨刻度参考尺 咖啡粉粗细参考',
#   'sale_month': '月销 99',
#   'skuValueName': ['研磨刻度参考尺（小黑卡）', '研磨刻度参考尺（冰箱贴）'],
#   'price': '28',
#   'sales_price': '22',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=669728674763&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.118.6808559f34xcn7',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO英砂咖啡分享壶 手冲家用套装 耐热玻璃 日式滴漏式咖啡器具',
#   'sale_month': '月销 36',
#   'skuValueName': ['英砂分享壶 450ml'],
#   'price': '58',
#   'sales_price': '48',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=630712094480&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.122.6808559f34xcn7&skuId=4657848298839',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO嘀嗒冰滴咖啡壶 冷萃咖啡滴滤壶 冰酿滴漏式茶壶 冷泡过滤杯',
#   'sale_month': '月销 30',
#   'skuValueName': ['嘀嗒冰滴壶'],
#   'price': '168',
#   'sales_price': '158',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=627367309291&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.126.6808559f34xcn7&skuId=4622087894010',
#   'total_sale': '1000+'},
#  {'item_name': 'MAVO 加入会员 先充值再购物',
#   'sale_month': '月销 73',
#   'skuValueName': ['面值C', '面值F', '面值H'],
#   'price': '600',
#   'sales_price': -1,
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=700097049053&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.130.6808559f34xcn7',
#   'total_sale': '100+'},
#  {'item_name': 'MAVO水滴咖啡量豆勺 短柄长柄定量粉勺 一次量取咖啡豆5/10g',
#   'sale_month': '月销 62',
#   'skuValueName': ['短量勺假日黄', '短量勺蜜瓜绿', '短量勺夜幕黑', '长量勺假日黄', '长量勺蜜瓜绿', '长量勺夜幕黑'],
#   'price': '18',
#   'sales_price': '16',
#   'link': 'https://detail.tmall.com/item.htm?abbucket=2&id=667383070673&rn=02e366a1de9d67ae546471fbf55d0f91&spm=a1z10.3-b-s.w4011-23533665189.134.6808559f34xcn7',
#   'total_sale': '1000+'}]

# %%
import pandas as pd
df = pd.DataFrame(result)

# %%
df
# Out:
#                                  item_name sale_month  \
# 0      MAVO巫师2.0手摇磨豆机 咖啡豆研磨机 手磨咖啡机磨豆器手动CNC   月销 1000+
# 1         MAVO手冲咖啡壶套装礼盒 咖啡全套 手冲壶磨豆机分享壶滤杯礼品    月销 500+
# 2         MAVO法压壶 咖啡壶过滤杯器具 茶壶手冲家用法式滤压 双层滤网    月销 500+
# 3      MAVO咖啡滤纸 手冲咖啡过滤纸 V60日本进口滤纸100张 可食用级    月销 200+
# 4        MAVO奶泡机 打奶泡器手持咖啡牛奶 打泡器手动奶泡壶 打发器玻璃    月销 400+
# 5        MAVO雪白法压壶 咖啡壶煮咖啡家用小型滤茶壶过滤杯 冬季限定玻璃    月销 400+
# 6         MAVO法压壶 咖啡壶橄榄木 咖啡过滤杯器具 茶壶家用法式压杯壶      月销 78
# 7         MAVO手冲壶手冲咖啡壶 挂耳咖啡器具滴漏 长嘴细口壶家用不锈钢      月销 61
# 8        MAVO手冲咖啡壶套装礼盒 全套咖啡器具家用便携 手冲壶分享壶滤杯    月销 100+
# 9          MAVO精灵咖啡电子秤 手冲咖啡秤称重 烘焙厨房吧台 智能计时      月销 71
# 10          MAVO 咖啡粉清洁气吹 磨豆机清洁 相机 精密仪器除尘工具    月销 200+
# 11         MAVO挂耳滤纸咖啡滤纸 咖啡滤袋手冲过滤纸 挂耳包咖啡过滤器    月销 100+
# 12       MAVO目黑手冲咖啡壶套装 过滤杯器具 细口长嘴滤壶 手冲杯分享壶      月销 43
# 13       MAVO尼德兰冷萃咖啡壶 冷泡冰滴咖啡壶 过滤杯冷萃茶壶 双层滤网      月销 47
# 14      MAVO咖啡豆保存罐 咖啡粉密封罐 玻璃抽真空 按压单向排气 大容量      月销 66
# 15       MAVO拾光师玻璃咖啡杯 马克杯 带手把ins风琥珀色粉红透明复古      月销 46
# 16  MAVO手冲咖啡滤杯 v60滤杯 家用咖啡器具套装 兼容v01v02滤纸陶瓷      月销 40
# 17        MAVO咖啡温度计 手冲打奶泡拉花温度计 不锈钢探针夹可水洗调节      月销 65
# 18       MAVO小鲸手冲咖啡壶套装 家用便携全套咖啡器具 手冲壶分享壶滤杯      月销 42
# 19                 MAVO小黑卡 研磨刻度参考尺 咖啡粉粗细参考      月销 99
# 20       MAVO英砂咖啡分享壶 手冲家用套装 耐热玻璃 日式滴漏式咖啡器具      月销 36
# 21       MAVO嘀嗒冰滴咖啡壶 冷萃咖啡滴滤壶 冰酿滴漏式茶壶 冷泡过滤杯      月销 30
# 22                        MAVO 加入会员 先充值再购物      月销 73
# 23       MAVO水滴咖啡量豆勺 短柄长柄定量粉勺 一次量取咖啡豆5/10g      月销 62
#
#                                          skuValueName price sales_price  \
# 0   [巫师1.0-全能版（深空灰）, 巫师1.0-全能版（粉金*深空灰）, 巫师1.0-全能版（...   298         288
# 1   [MAVO 2号咖啡集装箱-LITE版（黑色2.0）, MAVO 2号咖啡集装箱-LITE版...   599         559
# 2                          l 1-2人份, 600ml 2-3人份]    78          68
# 3                              [V01 100张入, V02 100张入]    35          33
# 4                                                [米白]    58          48
# 5   l 1-2人份（雪白）, 600ml 2-3人份（雪白）, 350ml 1-2人份...    68          58
# 6                          l 1-2人份, 600ml 2-3人份]   128         118
# 7                                  [曜岩黑X古铜, 水泥灰, 朱鹭白]   158         138
# 8          [MAVO小鲸套装 蜜瓜绿, MAVO小鲸套装 深空灰, MAVO小鲸套装 假日黄]   248         238
# 9                                                  []   168         158
# 10                                               [黑色]    38          -1
# 11                                           [50张 滤纸]    28          25
# 12                          [目黑·套装(手冲壶+滤杯+分享壶)赠黑石温度计]   218         198
# 13                                      [1200毫升 双层滤网]   138         128
# 14                             l, 800ml, 1200ml]    68          63
# 15                                       [琥珀, 樱粉, 透明]    28          23
# 16                                  [黑翼陶瓷滤杯 v01v02通用]    78          68
# 17                                        [无螺纹版, 螺纹版]    38          36
# 18                     [小鲸套装 蜜瓜绿, 小鲸套装 深空灰, 小鲸套装 假日黄]   248         238
# 19                       [研磨刻度参考尺（小黑卡）, 研磨刻度参考尺（冰箱贴）]    28          22
# 20                                      [英砂分享壶 450ml]    58          48
# 21                                            [嘀嗒冰滴壶]   168         158
# 22                                    [面值C, 面值F, 面值H]   600          -1
# 23   [短量勺假日黄, 短量勺蜜瓜绿, 短量勺夜幕黑, 长量勺假日黄, 长量勺蜜瓜绿, 长量勺夜幕黑]    18          16
#
#                                                  link total_sale
# 0   https://detail.tmall.com/item.htm?abbucket=2&i...        4万+
# 1   https://detail.tmall.com/item.htm?abbucket=2&i...        1万+
# 2   https://detail.tmall.com/item.htm?abbucket=2&i...        2万+
# 3   https://detail.tmall.com/item.htm?abbucket=2&i...      6000+
# 4   https://detail.tmall.com/item.htm?abbucket=2&i...        2万+
# 5   https://detail.tmall.com/item.htm?abbucket=2&i...      9000+
# 6   https://detail.tmall.com/item.htm?abbucket=2&i...      7000+
# 7   https://detail.tmall.com/item.htm?abbucket=2&i...      3000+
# 8   https://detail.tmall.com/item.htm?abbucket=2&i...       200+
# 9   https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 10  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 11  https://detail.tmall.com/item.htm?abbucket=2&i...      3000+
# 12  https://detail.tmall.com/item.htm?abbucket=2&i...      3000+
# 13  https://detail.tmall.com/item.htm?abbucket=2&i...      2000+
# 14  https://detail.tmall.com/item.htm?abbucket=2&i...        1万+
# 15  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 16  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 17  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 18  https://detail.tmall.com/item.htm?abbucket=2&i...       500+
# 19  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 20  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 21  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+
# 22  https://detail.tmall.com/item.htm?abbucket=2&i...       100+
# 23  https://detail.tmall.com/item.htm?abbucket=2&i...      1000+

# %%
df.to_excel("result.xlsx")
